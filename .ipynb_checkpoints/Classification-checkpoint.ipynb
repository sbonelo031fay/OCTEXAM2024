# %%
import pandas as pd # to load and analyze the dataset
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
#Loading the dataset
df = pd.read_csv("C:/Users/Lenovo/OneDrive/Desktop/OCT Exam 2024/Datasets/Teacher Salaries/teacher.csv")
df.head() #displaying the first 5 records of the dataset
# Out:
#    id degree  fte  years   base     fica  retirement     total
# 0   1     BA  1.0    5.0  45388  3472.18     7688.73  56548.91
# 1   2     MA  1.0   15.0  60649  4639.65    10273.94  75562.59
# 2   3     MA  1.0   16.0  60649  4639.65    10273.94  75562.59
# 3   4     BA  1.0   10.0  54466  4166.65     9226.54  67859.19
# 4   5     BA  1.0   26.0  65360  5000.04    11071.98  81432.02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          71 non-null     int64
#  1   degree      71 non-null     object
#  2   fte         71 non-null     float64
#  3   years       71 non-null     float64
#  4   base        71 non-null     int64
#  5   fica        71 non-null     float64
#  6   retirement  71 non-null     float64
#  7   total       71 non-null     float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 4.6+ KB

# %%
# checking missing values
missing_values = df.isnull().sum()
missing_values
# Out:
# id            0
# degree        0
# fte           0
# years         0
# base          0
# fica          0
# retirement    0
# total         0
# dtype: int64

# %%
# checking duplicates
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# Length: 71, dtype: bool

# %%
# Renaming columns for better readability and context
df.rename(columns={'degree': 'qualification','id': 'teacher_id','fte' : 'employment-status', 'base': 'base_annual_salary', 'years': 'years_employed', 'fica': 'fica_contribution', 'total': 'total_annual_salary', 'retirement': 'retirement_contribution'}, inplace=True)
df.columns
# Out:
# Index(['teacher_id', 'qualification', 'employment-status', 'years_employed',
#        'base_annual_salary', 'fica_contribution', 'retirement_contribution',
#        'total_annual_salary'],
#       dtype='object')

# %%
# counting the occurences of each employment status
employment_status_counts = df['employment-status'].value_counts()

# creating a bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=employment_status_counts.index, y=employment_status_counts.values, palette='viridis')
plt.title('Distribution of Employment Status')
plt.xlabel('Employment Status')
plt.ylabel('Number of Teachers')

plt.text(1.6, max(employment_status_counts.values) * 0.8, '0.5 = Part-Time', fontsize=12, color='blue')
plt.text(1.6, max(employment_status_counts.values) * 0.9, '1.0 = Full-Time', fontsize=12, color='green')
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_28108\3138823958.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=employment_status_counts.index, y=employment_status_counts.values, palette='viridis')

# %% [markdown]
# # 2. Box Plot for Salary Distribution by Qualification

# %%
# creating a Box Plot
plt.figure(figsize=(12, 6))
sns.boxplot(x='qualification', y='base_annual_salary', data=df, palette='coolwarm')
plt.title('Base Annual Salary Distribution by Qualification')
plt.xlabel('Qualification')
plt.ylabel('Base Annual Salary')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_28108\452304838.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='qualification', y='base_annual_salary', data=df, palette='coolwarm')

# %%
# filtering the dataset to only use the numberical columns
numerical_df = df.select_dtypes(include=['int64', 'float64'])

# correlation analysis
plt.figure(figsize=(10, 8))
correlation_matrix = numerical_df.corr()
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Summary statistics
df.describe()
# Out:
#        teacher_id  employment-status  years_employed  base_annual_salary  \
# count   71.000000          71.000000       71.000000           71.000000
# mean    36.873239           0.992958       15.873239        56415.957746
# std     20.834675           0.059339       10.804337         9984.217164
# min      1.000000           0.500000        0.000000        19900.000000
# 25%     19.500000           1.000000        7.500000        51174.000000
# 50%     37.000000           1.000000       14.000000        59914.000000
# 75%     54.500000           1.000000       25.500000        65360.000000
# max     72.000000           1.000000       40.000000        68230.000000
#
#        fica_contribution  retirement_contribution  total_annual_salary
# count          71.000000                71.000000            71.000000
# mean         4315.821127              9556.861831         70288.640704
# std           763.793275              1691.325623         12439.336063
# ...

# %%
# Binary encoding for the 'qualification' column
# 1 = MA, 0 = BA
df['qualification'] = df['qualification'].apply(lambda x: 1 if x == 'MA' else 0)

# Display the updated DataFrame
df.head()
# Out:
#    teacher_id  qualification  employment-status  years_employed  \
# 0           1              0                1.0             5.0
# 1           2              1                1.0            15.0
# 2           3              1                1.0            16.0
# 3           4              0                1.0            10.0
# 4           5              0                1.0            26.0
#
#    base_annual_salary  fica_contribution  retirement_contribution  \
# 0               45388            3472.18                  7688.73
# 1               60649            4639.65                 10273.94
# 2               60649            4639.65                 10273.94
# 3               54466            4166.65                  9226.54
# 4               65360            5000.04                 11071.98
#
#    total_annual_salary
# 0             56548.91
# 1             75562.59
# 2             75562.59
# 3             67859.19
# 4             81432.02

# %% [markdown]
# # Machine Learning Implementation

# %%
# Defining features (X) and target variables (y)
X = df.drop('employment-status', axis=1) # features
y = df['employment-status'] # target

# %%
# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Initializing the scaler
scaler = StandardScaler()

# Fit and transform the training data, and transform the test data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Initialize the Random Forest classifier
model = RandomForestClassifier()

# Fit the model on the training data
model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier()

# %%
# Make predictions on the test set
y_pred = model.predict(X_test_scaled)

# %% [raw]
# # Evaluating the model
# accuracy = accuracy_score(y_test, y_pred)
# conf_matrix = confusion_matrix(y_test, y_pred)
# class_report = classification_report(y_test, y_pred)

# %% [markdown]
# i am experiencing a mismatch error when evaluating the model and have run out of time for this model and had to move on to the next task
